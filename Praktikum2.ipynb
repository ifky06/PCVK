# %% [markdown]
# <a href="https://colab.research.google.com/github/ifky06/PCVK/blob/main/Praktikum2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ahmad Rifki Fauzi**
# # **TI-3B / 04**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
import matplotlib.pylab as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR->RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5=cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan file image
# cv.imwrite('/content/drive/MyDrive/PCVK/Images/Kitten1.jpg', cv.cvtColor(img5, cv.COLOR_BGR2RGB))

#tampilkan plot dengan ukuran kanvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=10)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **Pertanyaan**
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# > Jawab :
# Matplotlib memungkinkan tampilan gambar dalam notebook, sementara tanpa Matplotlib, gambar ditampilkan di jendela pop-up terpisah.
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# > Jawab :
# int16 lebih efisien dalam ukuran file dan memori dibandingkan int32 saat membuat gambar hitam.
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# > Jawab :
# Digunakan untuk menampilkan gambar dengan mudah dalam Google Colab tanpa harus menyimpannya terlebih dahulu.
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# > Jawab :
# Digunakan untuk membaca dan menulis berbagai format gambar dalam Scikit-Image, memungkinkan pengolahan gambar lebih lanjut.

# %%
#TUGAS NO 1
img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
print('Shape before using fig: ', img.shape)
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
print('Shape after using fig: ', img.shape)
ax.imshow(img)
# Out:
# Shape before using fig:  (225, 225, 3)
# Shape after using fig:  (225, 225, 3)

# %% [markdown]
# yang berubah hanya ukuran gambar saat ditampilkan, sedangkan ukuran asli gambar tidak berubah

# %%
#TUGAS2

#gambar dengan channel red dan blue
fig = plt.figure(figsize=(10, 10))
red_blue_img = img.copy()
red_blue_img[:,:,1]=0 # ubah channel hijau menjadi 0 (menghapus hijau)
ax = fig.add_subplot(221)
ax.imshow(red_blue_img)

#gambar dengan channel green dan blue
fig = plt.figure(figsize=(10, 10))
green_blue_img = img.copy()
green_blue_img[:,:,0]=0 # ubah channel merah menjadi 0 (menghapus meraj)
ax = fig.add_subplot(222)
ax.imshow(green_blue_img)

# %%
#TUGAS 3

img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

crop_img= img[20:115,25:120]

plt.imshow(crop_img)

# %%
#TUGAS4

img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

img_red = img[:,:,0]

crop_img= img_red[20:115,0:255]

plt.imshow(crop_img)

# %%
#TUGAS5

img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img,pt1=(10,50),pt2=(50,75),color=(0,255,0),thickness=4)
cv.rectangle(img,pt1=(60,50),pt2=(150,125),color=(0,255,255),thickness=4)
cv.rectangle(img,pt1=(10,85),pt2=(50,200),color=(0,0,255),thickness=4)
cv.rectangle(img,pt1=(160,50),pt2=(200,200),color=(255,0,255),thickness=4)
cv.rectangle(img,pt1=(60,135),pt2=(150,200),color=(255,0,0),thickness=4)
plt.imshow(img)

# %%
#TUGAS 6

img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img,pt1=(10,50),pt2=(50,75),color=(0,255,0),thickness=4)
cv.rectangle(img,pt1=(60,50),pt2=(150,125),color=(0,255,255),thickness=4)
cv.rectangle(img,pt1=(10,85),pt2=(50,200),color=(0,0,255),thickness=4)
cv.rectangle(img,pt1=(160,50),pt2=(200,200),color=(255,0,255),thickness=4)
cv.rectangle(img,pt1=(60,135),pt2=(150,200),color=(255,0,0),thickness=4)
img_flip = cv.flip(img, 0)
plt.imshow(img_flip)

# %%
#TUGAS 7

img = cv.imread('/content/drive/MyDrive/PCVK/fotosaya.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10, 10))

#persegi
rect_img = img.copy()
cv.rectangle(rect_img,pt1=(1300,900),pt2=(1750,1400),color=(0,255,0),thickness=20)
ax = fig.add_subplot(221)
ax.imshow(rect_img)

#lingkaran
crcl_img = img.copy()
cv.circle(crcl_img,center=(1550,1200),radius=250,color=(255,0,0),thickness=20)
ax = fig.add_subplot(222)
ax.imshow(crcl_img)

# %%
#TUGAS 8 dan 9
img = cv.imread('/content/drive/MyDrive/PCVK/Kitten1.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# Blue Channel
blue_channel = img[:,:,2]
# Rectangle
cv.rectangle(img,pt1=(30,175),pt2=(50,200),color=(0,0,255),thickness=4)
# Masukkan Text
cv.putText(img, text='Kitten', org=(75, 200), fontFace=font, fontScale=1, color=(0, 0, 255), thickness=2, lineType=cv.LINE_AA)
plt.imshow(blue_channel)

# %%
from google.colab import files
uploded_image = files.upload()
# Out:
#      <input type="file" id="files-d3b35df2-103f-4352-8ca5-8d3304231e4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3b35df2-103f-4352-8ca5-8d3304231e4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = "KTP.jpeg"
image = cv.imread(image_path)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

crcl_img = image_2.copy()
cv.circle(crcl_img,center=(640,200),radius=15,color=(255,0,0),thickness=3)
cv.circle(crcl_img,center=(695,200),radius=15,color=(0,255,0),thickness=3)
cv.circle(crcl_img,center=(670,255),radius=15,color=(0,0,255),thickness=3)
plt.imshow(crcl_img)
